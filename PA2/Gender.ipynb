# %%
# special IPython command to prepare the notebook for matplotlib
import matplotlib.pyplot as plt

#Array processing
import numpy as np
#Data analysis, wrangling and common exploratory operations
import pandas as pd
from pandas import Series, DataFrame
from itertools import chain
import datetime
#For visualization. Matplotlib for basic viz and seaborn for more stylish figures
# import matplotlib.pyplot as plt
import seaborn as snscx

# %%
#read the csv file into a Pandas data frame
df_data = pd.read_csv('Gender_classifier.csv', encoding='latin1')
df_data
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0      815719226    False   finalized                   3    10/26/15 23:24
# 1      815719227    False   finalized                   3    10/26/15 23:30
# 2      815719228    False   finalized                   3    10/26/15 23:33
# 3      815719229    False   finalized                   3    10/26/15 23:10
# 4      815719230    False   finalized                   3    10/27/15 01:15
# ...          ...      ...         ...                 ...               ...
# 20045  815757572     True      golden                 259               NaN
# 20046  815757681     True      golden                 248               NaN
# 20047  815757830     True      golden                 264               NaN
# 20048  815757921     True      golden                 250               NaN
# 20049  815757985     True      golden                 249               NaN
#
# ...

# %%
df = pd.read_csv('Gender_classifier.csv', encoding='latin1', usecols=['gender'])
s = df.gender
counts = s.value_counts()
counts
# Out:
# female     6700
# male       6194
# brand      5942
# unknown    1117
# Other        97
# Name: gender, dtype: int64

# %%
# df_f = pd.DataFrame(df_data)
# print (df_f)

# %%
topSevenRecords = df_data.head(7)
topSevenRecords
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3    10/27/15 01:15
# 5  815719231    False   finalized                   3    10/27/15 01:47
# 6  815719232    False   finalized                   3    10/27/15 01:57
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# 1    male             1.0000        yes                    1.0
# 2    male             0.6625        yes                    1.0
# 3    male             1.0000        yes                    1.0
# 4  female             1.0000        yes                    1.0
# ...

# %%
bottomSevenRecords = df_data.tail(7)
bottomSevenRecords
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 20043  815756700     True      golden                 240               NaN
# 20044  815756767     True      golden                 227               NaN
# 20045  815757572     True      golden                 259               NaN
# 20046  815757681     True      golden                 248               NaN
# 20047  815757830     True      golden                 264               NaN
# 20048  815757921     True      golden                 250               NaN
# 20049  815757985     True      golden                 249               NaN
#
#        gender  gender:confidence profile_yn  profile_yn:confidence  \
# 20043    male             1.0000        yes                    1.0
# 20044  female             1.0000        yes                    1.0
# 20045  female             1.0000        yes                    1.0
# 20046    male             1.0000        yes                    1.0
# ...

# %%
df_data.head(7).append(df_data.tail(7))
# Out:
# /var/folders/z4/fkls1k917_51fhgf9jbrkgd40000gn/T/ipykernel_1311/1364191184.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data.head(7).append(df_data.tail(7))
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0      815719226    False   finalized                   3    10/26/15 23:24
# 1      815719227    False   finalized                   3    10/26/15 23:30
# 2      815719228    False   finalized                   3    10/26/15 23:33
# 3      815719229    False   finalized                   3    10/26/15 23:10
# 4      815719230    False   finalized                   3    10/27/15 01:15
# 5      815719231    False   finalized                   3    10/27/15 01:47
# 6      815719232    False   finalized                   3    10/27/15 01:57
# 20043  815756700     True      golden                 240               NaN
# ...

# %%
df_data.dtypes
# Out:
# _unit_id                   int64
# _golden                     bool
# _unit_state               object
# _trusted_judgments         int64
# _last_judgment_at         object
# gender                    object
# gender:confidence        float64
# profile_yn                object
# profile_yn:confidence    float64
# created                   object
# description               object
# fav_number                 int64
# gender_gold               object
# link_color                object
# name                      object
# profile_yn_gold           object
# profileimage              object
# retweet_count              int64
# sidebar_color             object
# text                      object
# tweet_coord               object
# tweet_count                int64
# tweet_created             object
# tweet_id                 float64
# tweet_location            object
# user_timezone             object
# dtype: object

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [10], in <module>
# ----> 1 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
train, validate, test = \
              np.split(df_data.sample(frac=1, random_state=42), 
                       [int(.6*len(df_data)), int(.8*len(df_data))])

# %%
train
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 15589  815735081    False   finalized                   3  10/26/2015 23:44
# 18801  815738369    False   finalized                   3  10/26/2015 23:04
# 15905  815735406    False   finalized                   3  10/26/2015 23:06
# 4720   815724023    False   finalized                   3   10/27/2015 0:56
# 4885   815724191    False   finalized                   3  10/26/2015 23:05
# ...          ...      ...         ...                 ...               ...
# 8719   815728053    False   finalized                   3   10/27/2015 0:58
# 14399  815733862    False   finalized                   3  10/26/2015 22:02
# 13624  815733072    False   finalized                   3   10/27/2015 1:05
# 8146   815727468    False   finalized                   3   10/27/2015 1:27
# 7968   815727290    False   finalized                   3  10/26/2015 23:53
#
# ...

# %%
test
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 18280  815737833    False   finalized                   3  10/26/2015 23:37
# 2617   815721911    False   finalized                   3  10/26/2015 23:37
# 2411   815721703    False   finalized                   3   10/27/2015 1:44
# 1094   815720327    False   finalized                   3  10/26/2015 22:53
# 6065   815725375    False   finalized                   3   10/27/2015 1:52
# ...          ...      ...         ...                 ...               ...
# 11284  815730665    False   finalized                   3  10/26/2015 22:01
# 11964  815731365    False   finalized                   3  10/26/2015 23:16
# 5390   815724698    False   finalized                   3   10/27/2015 1:48
# 860    815720089    False   finalized                   3  10/26/2015 21:58
# 15795  815735291    False   finalized                   3   10/27/2015 1:28
#
# ...

# %%
validate
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 4264   815723563    False   finalized                   3  10/26/2015 23:50
# 19894  815739489    False   finalized                   3  10/26/2015 22:26
# 10652  815730019    False   finalized                   3   10/27/2015 0:19
# 6825   815726140    False   finalized                   3  10/26/2015 22:38
# 8113   815727435    False   finalized                   3   10/27/2015 1:22
# ...          ...      ...         ...                 ...               ...
# 2775   815722069    False   finalized                   3   10/27/2015 1:16
# 17167  815736693    False   finalized                   3   10/27/2015 1:24
# 4145   815723444    False   finalized                   3   10/27/2015 0:00
# 10515  815729882    False   finalized                   3  10/26/2015 22:17
# 8954   815728292    False   finalized                   3  10/26/2015 23:49
#
# ...

# %%
y = df_data.iloc[:,4].values
y
# Out:
# array(['10/26/2015 23:24', '10/26/2015 23:30', '10/26/2015 23:33', ...,
#        nan, nan, nan], dtype=object)
